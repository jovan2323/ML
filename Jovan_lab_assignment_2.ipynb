# %% [markdown]
# <a href="https://colab.research.google.com/github/jovan2323/ML/blob/main/Jovan_lab_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("DS to B.tech.xlsx")
print(df.head())
print(df.shape)
df.head()
# Out:
#    Id                                           Judgment  \
# 0   1  "1. Being aggrieved by the judgment delivered ...
# 1   2  "This was an appeal from a judgment and decree...
# 2   3  "This was an application under article 32 (1) ...
# 3   4  "APPEAL from a judgment of the High Court of H...
# 4   5  "APPEAL under article 374(4) of the Constituti...
#
#                                      Lawyers Summary  \
# 0   "The appeal was filed by a co-operative socie...
# 1   A complaint has been lodged against you, unde...
# 2   Appeal comes under article 374 (4) of the Con...
# 3  The appeal was presented to the Judicial Commi...
# 4  The appeal was presented to the Judicial Commi...
#
#                                       Golden summary Domain   Judgment Status  \
# 0  "The appellant, a cooperative society, filed a...  Civil  Appeal dismissed
# 1  "The appellants were members of the East India...  Civil  Appeal dismissed
# ...

# %%
import pandas as pd
import numpy as np
df1=pd.read_excel("ED.xlsx")
print(df1)
df1.head()
# Out:
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1   -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2    0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3    0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4    0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.019743 -0.071799  0.022546  0.049042 -0.005767 -0.016275 -0.037731
# 896  0.000186 -0.027604  0.010623  0.038237 -0.026675  0.020215 -0.040816
# 897  0.018066 -0.032152  0.039794  0.047608  0.003898  0.024092 -0.056508
# 898 -0.003492 -0.022739  0.021777  0.044054 -0.005621  0.013863 -0.079196
# 899  0.013689 -0.037855  0.039763  0.035750  0.004115  0.005637 -0.050556
#
#       embed_7   embed_8   embed_9  ...  embed_758  embed_759  embed_760  \
# ...

# %%
ndf = df1.join(df , lsuffix ="_left",rsuffix="_right",how="right")
ndf.head()
# Out:
#     embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0  0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1 -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2  0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3  0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4  0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
#
#     embed_7   embed_8   embed_9  ...  \
# 0  0.044483  0.019400 -0.017189  ...
# 1  0.039153  0.019596 -0.027138  ...
# 2  0.035118  0.035359 -0.029205  ...
# 3  0.044878  0.034781 -0.025772  ...
# 4  0.042820  0.029161 -0.015004  ...
#
#                                             Judgment  \
# 0  "1. Being aggrieved by the judgment delivered ...
# 1  "This was an appeal from a judgment and decree...
# 2  "This was an application under article 32 (1) ...
# 3  "APPEAL from a judgment of the High Court of H...
# ...

# %%
ndf = ndf.drop([ 'Court name','Link','Name','Equivalent Citation','Judgment Status','Domain','Golden summary','Lawyers Summary','Judgment'],axis=1)
ndf.head()
# Out:
#     embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0  0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1 -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2  0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3  0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4  0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
#
#     embed_7   embed_8   embed_9  ...  embed_760  embed_761  embed_762  \
# 0  0.044483  0.019400 -0.017189  ...  -0.008154  -0.056139   0.009890
# 1  0.039153  0.019596 -0.027138  ...  -0.006578  -0.034220   0.027574
# 2  0.035118  0.035359 -0.029205  ...  -0.034288  -0.050649   0.028408
# 3  0.044878  0.034781 -0.025772  ...  -0.018754  -0.053278   0.033005
# 4  0.042820  0.029161 -0.015004  ...  -0.010147  -0.035857   0.021784
#
#    embed_763  embed_764  embed_765  embed_766  embed_767  Id  Label
# ...

# %%
ndf = ndf.drop('Id',axis=1)
ndf.head()
# Out:
#     embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0  0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1 -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2  0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3  0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4  0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
#
#     embed_7   embed_8   embed_9  ...  \
# 0  0.044483  0.019400 -0.017189  ...
# 1  0.039153  0.019596 -0.027138  ...
# 2  0.035118  0.035359 -0.029205  ...
# 3  0.044878  0.034781 -0.025772  ...
# 4  0.042820  0.029161 -0.015004  ...
#
#                                             Judgment  \
# 0  "1. Being aggrieved by the judgment delivered ...
# 1  "This was an appeal from a judgment and decree...
# 2  "This was an application under article 32 (1) ...
# 3  "APPEAL from a judgment of the High Court of H...
# ...

# %%
ndf.to_excel('output.xlsx',index=False)

# %%
ndf1 = ndf.groupby('Label')
ndf1.first()
# Out:
#         embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# Label
# 0      0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1      0.020490 -0.033388  0.041006  0.048247  0.002952  0.010657 -0.055723
# 2      0.007590 -0.033201  0.027140  0.039872  0.018875  0.012731 -0.059900
# 3      0.017892 -0.035860  0.037331  0.028784 -0.016199  0.009888 -0.061992
# 4      0.016740 -0.017002  0.028802  0.032075 -0.000405  0.032477 -0.071542
# 5     -0.005725 -0.021073  0.013498  0.053032 -0.000702  0.023820 -0.063527
# 6      0.008779 -0.017713  0.024447  0.029281  0.009763  0.017475 -0.058008
# 7      0.020413 -0.006226  0.034637  0.038481  0.015681  0.002447 -0.058071
# 8      0.005784 -0.032630  0.016748  0.050207  0.016599  0.016654 -0.064409
# 9      0.011384 -0.037038  0.016547  0.055033 -0.016805  0.041571 -0.062358
# 10     0.012824 -0.025139  0.025475  0.030953  0.000106  0.018628 -0.072140
#
# ...

# %%
class_A_data = ndf[ndf['Label'] == 1]
class_B_data = ndf[ndf['Label'] == 2]

# %%
import numpy as np

centroid_A = np.mean(class_A_data, axis=0)
centroid_B = np.mean(class_B_data, axis=0)
# Out:
# C:\Users\srava\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# C:\Users\srava\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
centroid_A
# Out:
# embed_0      0.012932
# embed_1     -0.022711
# embed_2      0.022857
# embed_3      0.047338
# embed_4      0.007439
#                ...
# embed_765    0.015416
# embed_766   -0.022388
# embed_767   -0.020720
# Label        1.000000
# Link              NaN
# Length: 770, dtype: float64

# %%
centroid_B
# Out:
# embed_0      0.007989
# embed_1     -0.027470
# embed_2      0.033914
# embed_3      0.044745
# embed_4      0.001226
#                ...
# embed_765    0.012396
# embed_766   -0.018786
# embed_767   -0.022527
# Label        2.000000
# Link              NaN
# Length: 770, dtype: float64

# %%
centroid_A = np.std(class_A_data,axis=0)
centroid_B = np.std(class_B_data,axis=0)
# Out:
# C:\Users\srava\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3603: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# C:\Users\srava\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3603: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
centroid_A
centroid_B
# Out:
# embed_0      1.384450e-02
# embed_1      1.454708e-02
# embed_2      1.197324e-02
# embed_3      1.337186e-02
# embed_4      1.199154e-02
#                  ...
# embed_765    1.228411e-02
# embed_766    1.143357e-02
# embed_767    1.145999e-02
# Label        2.220446e-16
# Link                  NaN
# Length: 770, dtype: float64

# %%
x = np.linalg.norm(centroid_A - centroid_B)
x
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt

selected_feature = ndf['embed_0']
num_bins =10
hist, bins = np.histogram(selected_feature, bins=num_bins)

plt.hist(selected_feature, bins=num_bins,  color='w', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Selected Feature')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
vector1 = ndf.iloc[0, :]
vector2 = ndf.iloc[1, :]
distances = []
r_values = list(range(1, 11))
for r in r_values:
    distance = np.power(np.sum(np.abs(vector1 - vector2) ** r), 1/r)
    distances.append(distance)

plt.plot(r_values, distances, marker='o', linestyle='-')
plt.xlabel('r')
plt.ylabel('Minkowski Distance')
plt.title('Minkowski Distance vs. r')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...
